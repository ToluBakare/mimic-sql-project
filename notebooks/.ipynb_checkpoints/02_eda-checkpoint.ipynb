# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import dataclasses

# %%
df = pd.read_csv('../data/cohort.csv')

# %%
df.head(2)
# Out:
#    subject_id admission_type   hadm_id      condition  readmitted_30days  \
# 0    10000690       EW EMER.  26504700  Heart Failure                  0
# 1    10000980       EW EMER.  29654838  Heart Failure                  0
#
#    admit_time  disch_time  hospital_expire_flag gender  age_at_admission  \
# 0  2150-07-03  2150-07-07                     0      F                86
# 1  2188-01-03  2188-01-05                     0      F                75
#
#                      race marital_status insurance
# 0                   WHITE        WIDOWED  Medicare
# 1  BLACK/AFRICAN AMERICAN        MARRIED  Medicare

# %%
df.shape
# Out:
# (3485, 13)

# %%
df.isnull().sum()
# Out:
# subject_id               0
# admission_type           0
# hadm_id                  0
# condition                0
# readmitted_30days        0
# admit_time               0
# disch_time               0
# hospital_expire_flag     0
# gender                   0
# age_at_admission         0
# race                     0
# marital_status          92
# insurance               33
# dtype: int64

# %%
df.describe()
# Out:
#          subject_id       hadm_id  readmitted_30days  hospital_expire_flag  \
# count  3.485000e+03  3.485000e+03        3485.000000                3485.0
# mean   1.494011e+07  2.497560e+07           0.145768                   0.0
# std    2.908570e+06  2.868622e+06           0.352924                   0.0
# min    1.000069e+07  2.000030e+07           0.000000                   0.0
# 25%    1.242199e+07  2.247868e+07           0.000000                   0.0
# 50%    1.489925e+07  2.496850e+07           0.000000                   0.0
# 75%    1.744811e+07  2.745399e+07           0.000000                   0.0
# max    1.999962e+07  2.999766e+07           1.000000                   0.0
#
#        age_at_admission
# count       3485.000000
# mean          69.468293
# std           16.634655
# min           18.000000
# 25%           59.000000
# 50%           72.000000
# 75%           83.000000
# max           96.000000
